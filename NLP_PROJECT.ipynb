# %% [markdown]
# <a href="https://colab.research.google.com/github/srivaishnavi242/Automated-Speech-Recognition-for-Text-Conversion/blob/main/NLP_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 52.9 MB/s eta 0:00:00
# ...

# %%
# !apt-get update && apt-get install -y libportaudio2
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,381 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,812 kB]
# ...

# %%
import speech_recognition as sr
import IPython

# %%
male_path = "/content/drive/MyDrive/ColabNotebooks/male_voice.wav"
IPython.display.Audio(male_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
female_path = "/content/drive/MyDrive/ColabNotebooks/female_voice.wav"
IPython.display.Audio(female_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
r = sr.Recognizer()

# %%
def speech_to_text(audio_file):
    """
    Converts speech from an audio file to text.

    Args:
        audio_file (str): Path to the audio file.

    Returns:
        str: Transcribed text from the audio.
    """
    with sr.AudioFile(audio_file) as source:
        print("Processing the entire audio file...")
        audio_text = r.record(source)  # Record entire audio
        try:
            text = r.recognize_google(audio_text)
            print("Transcription complete.")
            return text
        except sr.UnknownValueError:
            print("Sorry, speech was not recognized.")
            return None
        except sr.RequestError:
            print("Could not request results; check your internet connection.")
            return None

# %%
# !pip install pydub

# %%
from pydub import AudioSegment

# Convert the file to proper WAV format
corrected_audio = AudioSegment.from_file(male_path)
corrected_audio = corrected_audio.set_channels(1).set_frame_rate(16000)

# Save the fixed file
male_fixed_path = "/content/drive/MyDrive/ColabNotebooks/male_fixed.wav"
corrected_audio.export(male_fixed_path, format="wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/ColabNotebooks/male_fixed.wav'>

# %%
speech_to_text(male_fixed_path)
predicted_text = speech_to_text(male_fixed_path)
print("Transcribed Text:\n")
words = predicted_text.split()
chunk_size = 10

for i in range(0, len(words), chunk_size):
    line = " ".join(words[i:i + chunk_size])
    print("•", line)
# Out:
# Processing the entire audio file...
# Transcription complete.
# Processing the entire audio file...
# Transcription complete.
# Transcribed Text:
#
# • but what if somebody decides to break it be careful
# • that you keep adequate coverage but look for places to
# • save money maybe it's taking longer to get things squared
# • away then the bankers expected hiring the wife for once
# • company may win her tax aided retirement income the Boost
# • is helpful but inadequate new self-deceiving Rags or hersley tossed
# • on the two naked bones what a discussion Canyon Sue
# • when the title of this type of song is in
# • question there's no dying or waxing or gassing needed paperweight
# • maybe personalized on black leather hard play work on a
# • flat surface and smooth out the simplest kind of separate
# • system uses a single self-contained unit the old shopping a
# • good mechanic is usually a bad boss both figures would
# ...

# %%
from pydub import AudioSegment

# Convert the file to proper WAV format
corrected_audio = AudioSegment.from_file(female_path)
corrected_audio = corrected_audio.set_channels(1).set_frame_rate(16000)

# Save the fixed file
female_fixed_path = "/content/drive/MyDrive/ColabNotebooks/female_fixed.wav"
corrected_audio.export(female_fixed_path, format="wav")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/ColabNotebooks/female_fixed.wav'>

# %%
speech_to_text(female_fixed_path)
transcribed_text = speech_to_text(female_fixed_path)
print("Transcribed Text:\n")
words = transcribed_text.split()
chunk_size = 10

for i in range(0, len(words), chunk_size):
    line = " ".join(words[i:i + chunk_size])
    print("•", line)
# Out:
# Processing the entire audio file...
# Transcription complete.
# Processing the entire audio file...
# Transcription complete.
# Transcribed Text:
#
# • perhaps this is what gives the aborigine his hot air
# • of dignity Rose as much as 50 ft in the
# • choreographer must arbitrate he did not however settled back into
# • acquiescence with things as they were he finds it in
# • utter misery and desolation ironically enough in this instance such
# • personal virtues were a luxury two other cases also were
# • under advisement say he is a horse thief runs an
# • old adage he may have a point in urging that
# • second things be given fewer prizes the straight line with
# • symbolize its uniqueness the circle of universe with Clay it
# • has multiple implications and possible headaches for marketing program no
# • manufacturer of his initiative and pointing out the cost Cricket
# • do you always navigate like

# %%
pip install -U openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 13.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 802.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# ...

# %%
import whisper
whisper_model = whisper.load_model("base")  # or "medium", "large" for better accuracy

# --- File paths ---
audio_path = "/content/drive/MyDrive/ColabNotebooks/male_fixed.wav"

# --- Generate Ground Truth using Whisper ---
result = whisper_model.transcribe(audio_path, language='en')
ground_truth = result["text"].strip()
print("Ground Truth (Whisper):")
words = predicted_text.split()
chunk_size = 10

for i in range(0, len(words), chunk_size):
    line = " ".join(words[i:i + chunk_size])
    print("•", line)
# Out:
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Ground Truth (Whisper):
# • but what if somebody decides to break it be careful
# • that you keep adequate coverage but look for places to
# • save money maybe it's taking longer to get things squared
# • away then the bankers expected hiring the wife for once
# • company may win her tax aided retirement income the Boost
# • is helpful but inadequate new self-deceiving Rags or hersley tossed
# • on the two naked bones what a discussion Canyon Sue
# • when the title of this type of song is in
# • question there's no dying or waxing or gassing needed paperweight
# • maybe personalized on black leather hard play work on a
# • flat surface and smooth out the simplest kind of separate
# • system uses a single self-contained unit the old shopping a
# ...

# %%
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from nltk.metrics import accuracy

# %%
# !pip install jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 29.3 MB/s eta 0:00:00
# ...

# %%
true_words = ground_truth.split()
pred_words = transcribed_text.split()
from jiwer import wer, cer
max_len = max(len(true_words), len(pred_words))
true_words += [""] * (max_len - len(true_words))
pred_words += [""] * (max_len - len(pred_words))

wer_score = wer(true_words, pred_words)
cer_score = cer(true_words, pred_words)
accuracy_percent = (1 - wer_score) * 100

print(f"\n Model Accuracy: {accuracy_percent:.2f}")
# Out:
#  Model Accuracy: 0.65

# %%
# --- Compute Confusion Matrix ---
cm = confusion_matrix(true_words, pred_words, labels=labels)

# --- Get the most common misclassified words ---
misclassified_counts = Counter(true_words)
top_words = [word for word, count in misclassified_counts.most_common(10)]  # Top 15

# --- Filter matrix for only top misclassified words ---
filtered_indices = [labels.index(word) for word in top_words if word in labels]
filtered_cm = cm[np.ix_(filtered_indices, filtered_indices)]
filtered_labels = [labels[i] for i in filtered_indices]

# --- Plot the Improved Confusion Matrix ---
fig, ax = plt.subplots(figsize=(7,5))  # Bigger figure size
disp = ConfusionMatrixDisplay(confusion_matrix=filtered_cm, display_labels=filtered_labels)
disp.plot(ax=ax, cmap="Blues")

# Rotate text labels properly
plt.xticks(rotation=60, ha="right")
plt.yticks(rotation=0)
plt.title("Confusion Matrix (Top 10 Misclassified Words)")
plt.show()
